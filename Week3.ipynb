# %%
import pandas as pd
from IPython.display import display

# List of player names
player_names = [
    "Colin Bergmann", "Brady Kindhart", "Dominic Sharp", "Elias Stevens",
    "Jordan Rosenberg", "Matthew Arnold", "Steven Schnieder", "Josh Herget",
    "Michael Gould", "Gavin Schacher", "Michael Long", "Camden Ruby",
    "Jack Zebig", "Aaris Stolte", "Andy Bunton", "Matt Schuler",
    "Harry Oden", "Nick Daugherty", "Jacob Hager", "Jordan Stucki",
    "Zach Liggett"
]

# Initialize an empty DataFrame for the team average
team_df = pd.DataFrame()

# Conditional formatting function
def highlight_changes(s, green_threshold, light_green_threshold, yellow_threshold, relative_metric=False):
    diff = s.diff()
    if relative_metric:
        pct_change = s.pct_change() * 100  # Percentage change for relative metrics like time to contact
        return [
            'background-color: green' if v <= -5 else
            'background-color: lightgreen' if -5 < v <= -2.5 else
            'background-color: yellow' if v >= 5 else
            'background-color: none'
            for v in pct_change
        ]
    else:
        return [
            'background-color: green' if v >= green_threshold else
            'background-color: lightgreen' if light_green_threshold <= v < green_threshold else
            'background-color: yellow' if v <= -yellow_threshold else
            'background-color: none'
            for v in diff
        ]

def main():
    global team_df  # Declare team_df as global so it can be modified inside this function

    excel_file = 'Sept23.xlsx'

    player_averages = []  # Store each player's average here

    for player in player_names:
        try:
            df = pd.read_excel(
                excel_file,
                sheet_name=player,
                engine='openpyxl',
                skiprows=8,
                usecols=['Date', 'Bat Speed (mph)', 'Rotational Acceleration (g)', 'Rotation Score', 'Plane Score', 'Connection Score', 'Time to Contact (sec)', 'Attack Angle (deg)']
            )

            df.dropna(inplace=True)
            df['Date'] = pd.to_datetime(df['Date'])
            df = df[df['Date'] >= '2023-09-07']
            df['Week'] = df['Date'].dt.to_period('W').dt.to_timestamp()

            df_grouped = df.groupby('Week').agg({
                'Bat Speed (mph)': ['max', 'mean'],
                'Rotational Acceleration (g)': ['max', 'mean'],
                'Rotation Score': ['mean'],
                'Plane Score': ['mean'],
                'Connection Score': ['mean'],
                'Time to Contact (sec)': ['mean'],
                'Attack Angle (deg)': ['mean', 'std']
            }).reset_index()

            df_grouped.columns = [f"{a}_{b}" if b else a for a, b in df_grouped.columns]

            # Add this player's average to the list
            player_averages.append(df_grouped)

            styled_result = df_grouped.style.apply(
                highlight_changes, subset=[
                    'Bat Speed (mph)_max', 'Bat Speed (mph)_mean'
                ], green_threshold=1.0, light_green_threshold=0.5, yellow_threshold=1.0
            ).apply(
                highlight_changes, subset=[
                    'Rotational Acceleration (g)_max', 'Rotational Acceleration (g)_mean'
                ], green_threshold=1.0, light_green_threshold=0.5, yellow_threshold=1.0
            ).apply(
                highlight_changes, subset=[
                    'Rotation Score_mean', 'Plane Score_mean', 'Connection Score_mean'
                ], green_threshold=1.5, light_green_threshold=0.75, yellow_threshold=1.5
            ).apply(
                highlight_changes, subset=[
                    'Time to Contact (sec)_mean'
                ], green_threshold=0, light_green_threshold=0, yellow_threshold=0, relative_metric=True
            )

            print(f"Data for {player}:")
            display(styled_result)

        except Exception as e:
            print(f"An error occurred while processing the sheet for {player}: {e}")

    # Calculate and display team averages
    team_avg_df = pd.concat(player_averages, ignore_index=True)
    team_avg = team_avg_df.groupby('Week').mean().reset_index()
    styled_team_avg = team_avg.style.apply(
        highlight_changes, subset=[
            'Bat Speed (mph)_max', 'Bat Speed (mph)_mean'
        ], green_threshold=1.0, light_green_threshold=0.5, yellow_threshold=1.0
    ).apply(
        highlight_changes, subset=[
            'Rotational Acceleration (g)_max', 'Rotational Acceleration (g)_mean'
        ], green_threshold=1.0, light_green_threshold=0.5, yellow_threshold=1.0
    ).apply(
        highlight_changes, subset=[
            'Rotation Score_mean', 'Plane Score_mean', 'Connection Score_mean'
        ], green_threshold=1.5, light_green_threshold=0.75, yellow_threshold=1.5
    ).apply(
        highlight_changes, subset=[
            'Time to Contact (sec)_mean'
        ], green_threshold=0, light_green_threshold=0, yellow_threshold=0, relative_metric=True
    )

    print("Team Average:")
    display(styled_team_avg)

if __name__ == "__main__":
    main()
# Out:
# Data for Colin Bergmann:
# <style  type="text/css" >
#     #T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col1 {
#             background-color:  none;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col2 {
#             background-color:  none;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col3 {
#             background-color:  none;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col4 {
#             background-color:  none;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col5 {
#             background-color:  none;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col6 {
#             background-color:  none;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col7 {
#             background-color:  none;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col8 {
#             background-color:  none;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col1 {
#             background-color:  green;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col2 {
#             background-color:  green;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col3 {
#             background-color:  yellow;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col4 {
#             background-color:  none;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col5 {
#             background-color:  none;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col6 {
#             background-color:  none;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col7 {
#             background-color:  green;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col8 {
#             background-color:  lightgreen;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col1 {
#             background-color:  green;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col2 {
#             background-color:  green;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col3 {
#             background-color:  yellow;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col4 {
#             background-color:  none;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col5 {
#             background-color:  lightgreen;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col6 {
#             background-color:  lightgreen;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col7 {
#             background-color:  none;
#         }    #T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col8 {
#             background-color:  none;
#         }</style><table id="T_600852f0_5c94_11ee_a152_88e9fe6939a8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Week</th>        <th class="col_heading level0 col1" >Bat Speed (mph)_max</th>        <th class="col_heading level0 col2" >Bat Speed (mph)_mean</th>        <th class="col_heading level0 col3" >Rotational Acceleration (g)_max</th>        <th class="col_heading level0 col4" >Rotational Acceleration (g)_mean</th>        <th class="col_heading level0 col5" >Rotation Score_mean</th>        <th class="col_heading level0 col6" >Plane Score_mean</th>        <th class="col_heading level0 col7" >Connection Score_mean</th>        <th class="col_heading level0 col8" >Time to Contact (sec)_mean</th>        <th class="col_heading level0 col9" >Attack Angle (deg)_mean</th>        <th class="col_heading level0 col10" >Attack Angle (deg)_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_600852f0_5c94_11ee_a152_88e9fe6939a8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col0" class="data row0 col0" >2023-09-04 00:00:00</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col1" class="data row0 col1" >74.600000</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col2" class="data row0 col2" >68.423698</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col3" class="data row0 col3" >18.700000</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col4" class="data row0 col4" >10.566667</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col5" class="data row0 col5" >44.361979</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col6" class="data row0 col6" >54.807292</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col7" class="data row0 col7" >57.776042</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col8" class="data row0 col8" >0.152526</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col9" class="data row0 col9" >11.265625</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row0_col10" class="data row0 col10" >4.832145</td>
#             </tr>
#             <tr>
#                         <th id="T_600852f0_5c94_11ee_a152_88e9fe6939a8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col0" class="data row1 col0" >2023-09-11 00:00:00</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col1" class="data row1 col1" >76.600000</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col2" class="data row1 col2" >69.528625</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col3" class="data row1 col3" >17.200000</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col4" class="data row1 col4" >10.318959</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col5" class="data row1 col5" >43.799257</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col6" class="data row1 col6" >54.680297</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col7" class="data row1 col7" >60.189591</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col8" class="data row1 col8" >0.147621</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col9" class="data row1 col9" >8.702602</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row1_col10" class="data row1 col10" >4.879980</td>
#             </tr>
#             <tr>
#                         <th id="T_600852f0_5c94_11ee_a152_88e9fe6939a8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col0" class="data row2 col0" >2023-09-18 00:00:00</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col1" class="data row2 col1" >77.900000</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col2" class="data row2 col2" >72.662667</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col3" class="data row2 col3" >15.000000</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col4" class="data row2 col4" >10.713333</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col5" class="data row2 col5" >44.760000</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col6" class="data row2 col6" >56.000000</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col7" class="data row2 col7" >59.586667</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col8" class="data row2 col8" >0.149600</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col9" class="data row2 col9" >10.080000</td>
#                         <td id="T_600852f0_5c94_11ee_a152_88e9fe6939a8row2_col10" class="data row2 col10" >4.823254</td>
#             </tr>
#     </tbody></table>
# Data for Brady Kindhart:
# <style  type="text/css" >
#     #T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col1 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col2 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col3 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col4 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col5 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col6 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col7 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col8 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col1 {
#             background-color:  green;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col2 {
#             background-color:  green;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col3 {
#             background-color:  green;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col4 {
#             background-color:  lightgreen;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col5 {
#             background-color:  green;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col6 {
#             background-color:  yellow;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col7 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col8 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col1 {
#             background-color:  green;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col2 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col3 {
#             background-color:  yellow;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col4 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col5 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col6 {
#             background-color:  none;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col7 {
#             background-color:  green;
#         }    #T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col8 {
#             background-color:  none;
#         }</style><table id="T_61011804_5c94_11ee_a152_88e9fe6939a8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Week</th>        <th class="col_heading level0 col1" >Bat Speed (mph)_max</th>        <th class="col_heading level0 col2" >Bat Speed (mph)_mean</th>        <th class="col_heading level0 col3" >Rotational Acceleration (g)_max</th>        <th class="col_heading level0 col4" >Rotational Acceleration (g)_mean</th>        <th class="col_heading level0 col5" >Rotation Score_mean</th>        <th class="col_heading level0 col6" >Plane Score_mean</th>        <th class="col_heading level0 col7" >Connection Score_mean</th>        <th class="col_heading level0 col8" >Time to Contact (sec)_mean</th>        <th class="col_heading level0 col9" >Attack Angle (deg)_mean</th>        <th class="col_heading level0 col10" >Attack Angle (deg)_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61011804_5c94_11ee_a152_88e9fe6939a8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col0" class="data row0 col0" >2023-09-04 00:00:00</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col1" class="data row0 col1" >72.800000</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col2" class="data row0 col2" >67.603797</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col3" class="data row0 col3" >18.300000</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col4" class="data row0 col4" >13.063291</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col5" class="data row0 col5" >50.449367</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col6" class="data row0 col6" >63.189873</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col7" class="data row0 col7" >56.962025</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col8" class="data row0 col8" >0.153671</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col9" class="data row0 col9" >11.911392</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row0_col10" class="data row0 col10" >5.040448</td>
#             </tr>
#             <tr>
#                         <th id="T_61011804_5c94_11ee_a152_88e9fe6939a8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col0" class="data row1 col0" >2023-09-11 00:00:00</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col1" class="data row1 col1" >74.100000</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col2" class="data row1 col2" >68.908517</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col3" class="data row1 col3" >19.800000</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col4" class="data row1 col4" >13.950789</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col5" class="data row1 col5" >52.586751</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col6" class="data row1 col6" >60.823344</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col7" class="data row1 col7" >55.851735</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col8" class="data row1 col8" >0.150189</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col9" class="data row1 col9" >12.015773</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row1_col10" class="data row1 col10" >6.073110</td>
#             </tr>
#             <tr>
#                         <th id="T_61011804_5c94_11ee_a152_88e9fe6939a8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col0" class="data row2 col0" >2023-09-18 00:00:00</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col1" class="data row2 col1" >76.600000</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col2" class="data row2 col2" >69.204839</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col3" class="data row2 col3" >18.700000</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col4" class="data row2 col4" >14.022581</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col5" class="data row2 col5" >52.741935</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col6" class="data row2 col6" >60.500000</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col7" class="data row2 col7" >57.870968</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col8" class="data row2 col8" >0.148710</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col9" class="data row2 col9" >12.612903</td>
#                         <td id="T_61011804_5c94_11ee_a152_88e9fe6939a8row2_col10" class="data row2 col10" >6.039094</td>
#             </tr>
#     </tbody></table>
# Data for Dominic Sharp:
# <style  type="text/css" >
#     #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col1 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col2 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col3 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col4 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col5 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col6 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col7 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col8 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col1 {
#             background-color:  green;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col2 {
#             background-color:  lightgreen;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col3 {
#             background-color:  green;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col4 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col5 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col6 {
#             background-color:  yellow;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col7 {
#             background-color:  yellow;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col8 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col1 {
#             background-color:  yellow;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col2 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col3 {
#             background-color:  yellow;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col4 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col5 {
#             background-color:  none;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col6 {
#             background-color:  green;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col7 {
#             background-color:  green;
#         }    #T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col8 {
#             background-color:  none;
#         }</style><table id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Week</th>        <th class="col_heading level0 col1" >Bat Speed (mph)_max</th>        <th class="col_heading level0 col2" >Bat Speed (mph)_mean</th>        <th class="col_heading level0 col3" >Rotational Acceleration (g)_max</th>        <th class="col_heading level0 col4" >Rotational Acceleration (g)_mean</th>        <th class="col_heading level0 col5" >Rotation Score_mean</th>        <th class="col_heading level0 col6" >Plane Score_mean</th>        <th class="col_heading level0 col7" >Connection Score_mean</th>        <th class="col_heading level0 col8" >Time to Contact (sec)_mean</th>        <th class="col_heading level0 col9" >Attack Angle (deg)_mean</th>        <th class="col_heading level0 col10" >Attack Angle (deg)_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col0" class="data row0 col0" >2023-09-04 00:00:00</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col1" class="data row0 col1" >70.100000</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col2" class="data row0 col2" >65.631980</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col3" class="data row0 col3" >20.100000</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col4" class="data row0 col4" >15.548223</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col5" class="data row0 col5" >56.441624</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col6" class="data row0 col6" >49.583756</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col7" class="data row0 col7" >57.421320</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col8" class="data row0 col8" >0.148629</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col9" class="data row0 col9" >12.812183</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row0_col10" class="data row0 col10" >4.556925</td>
#             </tr>
#             <tr>
#                         <th id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col0" class="data row1 col0" >2023-09-11 00:00:00</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col1" class="data row1 col1" >77.800000</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col2" class="data row1 col2" >66.253689</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col3" class="data row1 col3" >22.300000</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col4" class="data row1 col4" >15.061066</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col5" class="data row1 col5" >55.307377</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col6" class="data row1 col6" >47.713115</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col7" class="data row1 col7" >55.377049</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col8" class="data row1 col8" >0.148443</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col9" class="data row1 col9" >11.954918</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row1_col10" class="data row1 col10" >5.758695</td>
#             </tr>
#             <tr>
#                         <th id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col0" class="data row2 col0" >2023-09-18 00:00:00</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col1" class="data row2 col1" >68.600000</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col2" class="data row2 col2" >65.586364</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col3" class="data row2 col3" >20.400000</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col4" class="data row2 col4" >15.004545</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col5" class="data row2 col5" >55.181818</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col6" class="data row2 col6" >55.636364</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col7" class="data row2 col7" >60.795455</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col8" class="data row2 col8" >0.145000</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col9" class="data row2 col9" >10.522727</td>
#                         <td id="T_61fda6aa_5c94_11ee_a152_88e9fe6939a8row2_col10" class="data row2 col10" >7.157655</td>
#             </tr>
#     </tbody></table>
# Data for Elias Stevens:
# <style  type="text/css" >
#     #T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col1 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col2 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col3 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col4 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col5 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col6 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col7 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col8 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col1 {
#             background-color:  green;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col2 {
#             background-color:  green;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col3 {
#             background-color:  green;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col4 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col5 {
#             background-color:  lightgreen;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col6 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col7 {
#             background-color:  green;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col8 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col1 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col2 {
#             background-color:  yellow;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col3 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col4 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col5 {
#             background-color:  yellow;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col6 {
#             background-color:  none;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col7 {
#             background-color:  yellow;
#         }    #T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col8 {
#             background-color:  none;
#         }</style><table id="T_62eac390_5c94_11ee_a152_88e9fe6939a8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Week</th>        <th class="col_heading level0 col1" >Bat Speed (mph)_max</th>        <th class="col_heading level0 col2" >Bat Speed (mph)_mean</th>        <th class="col_heading level0 col3" >Rotational Acceleration (g)_max</th>        <th class="col_heading level0 col4" >Rotational Acceleration (g)_mean</th>        <th class="col_heading level0 col5" >Rotation Score_mean</th>        <th class="col_heading level0 col6" >Plane Score_mean</th>        <th class="col_heading level0 col7" >Connection Score_mean</th>        <th class="col_heading level0 col8" >Time to Contact (sec)_mean</th>        <th class="col_heading level0 col9" >Attack Angle (deg)_mean</th>        <th class="col_heading level0 col10" >Attack Angle (deg)_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62eac390_5c94_11ee_a152_88e9fe6939a8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col0" class="data row0 col0" >2023-09-04 00:00:00</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col1" class="data row0 col1" >75.900000</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col2" class="data row0 col2" >69.640909</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col3" class="data row0 col3" >22.300000</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col4" class="data row0 col4" >14.988636</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col5" class="data row0 col5" >55.068182</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col6" class="data row0 col6" >45.215909</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col7" class="data row0 col7" >57.125000</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col8" class="data row0 col8" >0.148864</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col9" class="data row0 col9" >10.875000</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row0_col10" class="data row0 col10" >5.087312</td>
#             </tr>
#             <tr>
#                         <th id="T_62eac390_5c94_11ee_a152_88e9fe6939a8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col0" class="data row1 col0" >2023-09-11 00:00:00</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col1" class="data row1 col1" >77.300000</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col2" class="data row1 col2" >70.878986</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col3" class="data row1 col3" >23.700000</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col4" class="data row1 col4" >15.343478</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col5" class="data row1 col5" >55.974638</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col6" class="data row1 col6" >44.894928</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col7" class="data row1 col7" >59.271739</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col8" class="data row1 col8" >0.147319</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col9" class="data row1 col9" >11.184783</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row1_col10" class="data row1 col10" >5.507541</td>
#             </tr>
#             <tr>
#                         <th id="T_62eac390_5c94_11ee_a152_88e9fe6939a8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col0" class="data row2 col0" >2023-09-18 00:00:00</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col1" class="data row2 col1" >76.900000</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col2" class="data row2 col2" >69.764062</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col3" class="data row2 col3" >23.600000</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col4" class="data row2 col4" >14.353125</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col5" class="data row2 col5" >53.593750</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col6" class="data row2 col6" >44.757812</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col7" class="data row2 col7" >54.148438</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col8" class="data row2 col8" >0.153125</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col9" class="data row2 col9" >13.359375</td>
#                         <td id="T_62eac390_5c94_11ee_a152_88e9fe6939a8row2_col10" class="data row2 col10" >5.005091</td>
#             </tr>
#     </tbody></table>
# Data for Jordan Rosenberg:
# <style  type="text/css" >
#     #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col1 {
#             background-color:  none;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col2 {
#             background-color:  none;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col3 {
#             background-color:  none;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col4 {
#             background-color:  none;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col5 {
#             background-color:  none;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col6 {
#             background-color:  none;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col7 {
#             background-color:  none;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col8 {
#             background-color:  none;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col1 {
#             background-color:  green;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col2 {
#             background-color:  green;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col3 {
#             background-color:  green;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col4 {
#             background-color:  lightgreen;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col5 {
#             background-color:  lightgreen;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col6 {
#             background-color:  yellow;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col7 {
#             background-color:  yellow;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col8 {
#             background-color:  lightgreen;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col1 {
#             background-color:  green;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col2 {
#             background-color:  green;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col3 {
#             background-color:  lightgreen;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col4 {
#             background-color:  green;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col5 {
#             background-color:  green;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col6 {
#             background-color:  none;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col7 {
#             background-color:  green;
#         }    #T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col8 {
#             background-color:  none;
#         }</style><table id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Week</th>        <th class="col_heading level0 col1" >Bat Speed (mph)_max</th>        <th class="col_heading level0 col2" >Bat Speed (mph)_mean</th>        <th class="col_heading level0 col3" >Rotational Acceleration (g)_max</th>        <th class="col_heading level0 col4" >Rotational Acceleration (g)_mean</th>        <th class="col_heading level0 col5" >Rotation Score_mean</th>        <th class="col_heading level0 col6" >Plane Score_mean</th>        <th class="col_heading level0 col7" >Connection Score_mean</th>        <th class="col_heading level0 col8" >Time to Contact (sec)_mean</th>        <th class="col_heading level0 col9" >Attack Angle (deg)_mean</th>        <th class="col_heading level0 col10" >Attack Angle (deg)_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col0" class="data row0 col0" >2023-09-04 00:00:00</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col1" class="data row0 col1" >70.800000</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col2" class="data row0 col2" >62.381250</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col3" class="data row0 col3" >12.900000</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col4" class="data row0 col4" >8.492614</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col5" class="data row0 col5" >39.329545</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col6" class="data row0 col6" >44.448864</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col7" class="data row0 col7" >40.034091</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col8" class="data row0 col8" >0.162784</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col9" class="data row0 col9" >15.897727</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row0_col10" class="data row0 col10" >7.265637</td>
#             </tr>
#             <tr>
#                         <th id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col0" class="data row1 col0" >2023-09-11 00:00:00</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col1" class="data row1 col1" >72.500000</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col2" class="data row1 col2" >64.944041</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col3" class="data row1 col3" >13.900000</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col4" class="data row1 col4" >9.100518</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col5" class="data row1 col5" >40.818653</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col6" class="data row1 col6" >40.165803</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col7" class="data row1 col7" >35.673575</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col8" class="data row1 col8" >0.158601</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col9" class="data row1 col9" >15.279793</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row1_col10" class="data row1 col10" >6.501959</td>
#             </tr>
#             <tr>
#                         <th id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col0" class="data row2 col0" >2023-09-18 00:00:00</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col1" class="data row2 col1" >75.500000</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col2" class="data row2 col2" >66.828070</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col3" class="data row2 col3" >14.400000</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col4" class="data row2 col4" >10.483333</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col5" class="data row2 col5" >44.157895</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col6" class="data row2 col6" >39.508772</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col7" class="data row2 col7" >37.508772</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col8" class="data row2 col8" >0.156316</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col9" class="data row2 col9" >18.710526</td>
#                         <td id="T_63d82e46_5c94_11ee_a152_88e9fe6939a8row2_col10" class="data row2 col10" >8.193159</td>
#             </tr>
#     </tbody></table>
# Data for Matthew Arnold:
# <style  type="text/css" >
#     #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col1 {
#             background-color:  none;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col2 {
#             background-color:  none;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col3 {
#             background-color:  none;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col4 {
#             background-color:  none;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col5 {
#             background-color:  none;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col6 {
#             background-color:  none;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col7 {
#             background-color:  none;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col8 {
#             background-color:  none;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col1 {
#             background-color:  lightgreen;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col2 {
#             background-color:  green;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col3 {
#             background-color:  lightgreen;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col4 {
#             background-color:  none;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col5 {
#             background-color:  none;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col6 {
#             background-color:  green;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col7 {
#             background-color:  none;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col8 {
#             background-color:  lightgreen;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col1 {
#             background-color:  yellow;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col2 {
#             background-color:  yellow;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col3 {
#             background-color:  none;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col4 {
#             background-color:  none;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col5 {
#             background-color:  lightgreen;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col6 {
#             background-color:  green;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col7 {
#             background-color:  green;
#         }    #T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col8 {
#             background-color:  none;
#         }</style><table id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Week</th>        <th class="col_heading level0 col1" >Bat Speed (mph)_max</th>        <th class="col_heading level0 col2" >Bat Speed (mph)_mean</th>        <th class="col_heading level0 col3" >Rotational Acceleration (g)_max</th>        <th class="col_heading level0 col4" >Rotational Acceleration (g)_mean</th>        <th class="col_heading level0 col5" >Rotation Score_mean</th>        <th class="col_heading level0 col6" >Plane Score_mean</th>        <th class="col_heading level0 col7" >Connection Score_mean</th>        <th class="col_heading level0 col8" >Time to Contact (sec)_mean</th>        <th class="col_heading level0 col9" >Attack Angle (deg)_mean</th>        <th class="col_heading level0 col10" >Attack Angle (deg)_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col0" class="data row0 col0" >2023-09-04 00:00:00</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col1" class="data row0 col1" >75.300000</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col2" class="data row0 col2" >67.723881</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col3" class="data row0 col3" >14.100000</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col4" class="data row0 col4" >11.208209</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col5" class="data row0 col5" >45.940299</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col6" class="data row0 col6" >36.940299</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col7" class="data row0 col7" >55.694030</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col8" class="data row0 col8" >0.151716</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col9" class="data row0 col9" >15.776119</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row0_col10" class="data row0 col10" >4.254395</td>
#             </tr>
#             <tr>
#                         <th id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col0" class="data row1 col0" >2023-09-11 00:00:00</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col1" class="data row1 col1" >76.000000</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col2" class="data row1 col2" >69.252941</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col3" class="data row1 col3" >14.700000</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col4" class="data row1 col4" >10.887395</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col5" class="data row1 col5" >45.117647</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col6" class="data row1 col6" >44.285714</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col7" class="data row1 col7" >55.151261</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col8" class="data row1 col8" >0.146891</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col9" class="data row1 col9" >12.941176</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row1_col10" class="data row1 col10" >5.434189</td>
#             </tr>
#             <tr>
#                         <th id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col0" class="data row2 col0" >2023-09-18 00:00:00</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col1" class="data row2 col1" >73.900000</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col2" class="data row2 col2" >67.389286</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col3" class="data row2 col3" >14.600000</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col4" class="data row2 col4" >11.235714</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col5" class="data row2 col5" >46.047619</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col6" class="data row2 col6" >48.309524</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col7" class="data row2 col7" >57.047619</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col8" class="data row2 col8" >0.146786</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col9" class="data row2 col9" >10.714286</td>
#                         <td id="T_64d0fd6e_5c94_11ee_a152_88e9fe6939a8row2_col10" class="data row2 col10" >8.005377</td>
#             </tr>
#     </tbody></table>
# Data for Steven Schnieder:
# <style  type="text/css" >
#     #T_65d0598a_5c94_11ee_a152_88e9fe6939a8row0_col1 {
#             background-color:  none;
#         }    #T_65d0598a_5c94_11ee_a152_88e9fe6939a8row0_col2 {
#             background-color:  none;
#         }    #T_65d0598a_5c94_11ee_a152_88e9fe6939a8row0_col3 {
#             background-color:  none;
#         }    #T_65d0598a_5c94_11ee_a152_88e9fe6939a8row0_col4 {
#             background-color:  none;
#         }    #T_65d0598a_5c94_11ee_a152_88e9fe6939a8row0_col5 {
# ...
#             <tr>
#                         <th id="T_70b97ca0_5c94_11ee_a152_88e9fe6939a8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_70b97ca0_5c94_11ee_a152_88e9fe6939a8row2_col0" class="data row2 col0" >2023-09-18 00:00:00</td>
#                         <td id="T_70b97ca0_5c94_11ee_a152_88e9fe6939a8row2_col1" class="data row2 col1" >77.900000</td>
#                         <td id="T_70b97ca0_5c94_11ee_a152_88e9fe6939a8row2_col2" class="data row2 col2" >71.328571</td>
#                         <td id="T_70b97ca0_5c94_11ee_a152_88e9fe6939a8row2_col3" class="data row2 col3" >18.600000</td>
#                         <td id="T_70b97ca0_5c94_11ee_a152_88e9fe6939a8row2_col4" class="data row2 col4" >15.048980</td>
#                         <td id="T_70b97ca0_5c94_11ee_a152_88e9fe6939a8row2_col5" class="data row2 col5" >55.244898</td>
#                         <td id="T_70b97ca0_5c94_11ee_a152_88e9fe6939a8row2_col6" class="data row2 col6" >53.775510</td>
#                         <td id="T_70b97ca0_5c94_11ee_a152_88e9fe6939a8row2_col7" class="data row2 col7" >56.795918</td>
#                         <td id="T_70b97ca0_5c94_11ee_a152_88e9fe6939a8row2_col8" class="data row2 col8" >0.144490</td>
#                         <td id="T_70b97ca0_5c94_11ee_a152_88e9fe6939a8row2_col9" class="data row2 col9" >6.734694</td>
#                         <td id="T_70b97ca0_5c94_11ee_a152_88e9fe6939a8row2_col10" class="data row2 col10" >5.118494</td>
#             </tr>
#     </tbody></table>
# Data for Jordan Stucki:
# <style  type="text/css" >
# </style><table id="T_7183313a_5c94_11ee_a152_88e9fe6939a8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Week</th>        <th class="col_heading level0 col1" >Bat Speed (mph)_max</th>        <th class="col_heading level0 col2" >Bat Speed (mph)_mean</th>        <th class="col_heading level0 col3" >Rotational Acceleration (g)_max</th>        <th class="col_heading level0 col4" >Rotational Acceleration (g)_mean</th>        <th class="col_heading level0 col5" >Rotation Score_mean</th>        <th class="col_heading level0 col6" >Plane Score_mean</th>        <th class="col_heading level0 col7" >Connection Score_mean</th>        <th class="col_heading level0 col8" >Time to Contact (sec)_mean</th>        <th class="col_heading level0 col9" >Attack Angle (deg)_mean</th>        <th class="col_heading level0 col10" >Attack Angle (deg)_std</th>    </tr></thead><tbody>
#         </tbody></table>
# Data for Zach Liggett:
# <style  type="text/css" >
#     #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col1 {
#             background-color:  none;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col2 {
#             background-color:  none;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col3 {
#             background-color:  none;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col4 {
#             background-color:  none;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col5 {
#             background-color:  none;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col6 {
#             background-color:  none;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col7 {
#             background-color:  none;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col8 {
#             background-color:  none;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col1 {
#             background-color:  green;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col2 {
#             background-color:  green;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col3 {
#             background-color:  green;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col4 {
#             background-color:  none;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col5 {
#             background-color:  none;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col6 {
#             background-color:  green;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col7 {
#             background-color:  yellow;
#         }    #T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col8 {
#             background-color:  none;
#         }</style><table id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Week</th>        <th class="col_heading level0 col1" >Bat Speed (mph)_max</th>        <th class="col_heading level0 col2" >Bat Speed (mph)_mean</th>        <th class="col_heading level0 col3" >Rotational Acceleration (g)_max</th>        <th class="col_heading level0 col4" >Rotational Acceleration (g)_mean</th>        <th class="col_heading level0 col5" >Rotation Score_mean</th>        <th class="col_heading level0 col6" >Plane Score_mean</th>        <th class="col_heading level0 col7" >Connection Score_mean</th>        <th class="col_heading level0 col8" >Time to Contact (sec)_mean</th>        <th class="col_heading level0 col9" >Attack Angle (deg)_mean</th>        <th class="col_heading level0 col10" >Attack Angle (deg)_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col0" class="data row0 col0" >2023-09-11 00:00:00</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col1" class="data row0 col1" >71.500000</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col2" class="data row0 col2" >66.072072</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col3" class="data row0 col3" >19.500000</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col4" class="data row0 col4" >14.619820</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col5" class="data row0 col5" >54.153153</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col6" class="data row0 col6" >59.099099</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col7" class="data row0 col7" >60.657658</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col8" class="data row0 col8" >0.148559</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col9" class="data row0 col9" >5.621622</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row0_col10" class="data row0 col10" >7.542671</td>
#             </tr>
#             <tr>
#                         <th id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col0" class="data row1 col0" >2023-09-18 00:00:00</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col1" class="data row1 col1" >74.100000</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col2" class="data row1 col2" >67.667626</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col3" class="data row1 col3" >21.200000</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col4" class="data row1 col4" >14.417986</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col5" class="data row1 col5" >53.697842</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col6" class="data row1 col6" >62.647482</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col7" class="data row1 col7" >56.546763</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col8" class="data row1 col8" >0.147626</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col9" class="data row1 col9" >5.913669</td>
#                         <td id="T_7258ab62_5c94_11ee_a152_88e9fe6939a8row1_col10" class="data row1 col10" >8.770406</td>
#             </tr>
#     </tbody></table>
# Team Average:
# <style  type="text/css" >
#     #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col1 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col2 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col3 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col4 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col5 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col6 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col7 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col8 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col1 {
#             background-color:  lightgreen;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col2 {
#             background-color:  lightgreen;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col3 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col4 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col5 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col6 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col7 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col8 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col1 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col2 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col3 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col4 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col5 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col6 {
#             background-color:  lightgreen;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col7 {
#             background-color:  none;
#         }    #T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col8 {
#             background-color:  none;
#         }</style><table id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Week</th>        <th class="col_heading level0 col1" >Bat Speed (mph)_max</th>        <th class="col_heading level0 col2" >Bat Speed (mph)_mean</th>        <th class="col_heading level0 col3" >Rotational Acceleration (g)_max</th>        <th class="col_heading level0 col4" >Rotational Acceleration (g)_mean</th>        <th class="col_heading level0 col5" >Rotation Score_mean</th>        <th class="col_heading level0 col6" >Plane Score_mean</th>        <th class="col_heading level0 col7" >Connection Score_mean</th>        <th class="col_heading level0 col8" >Time to Contact (sec)_mean</th>        <th class="col_heading level0 col9" >Attack Angle (deg)_mean</th>        <th class="col_heading level0 col10" >Attack Angle (deg)_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col0" class="data row0 col0" >2023-09-04 00:00:00</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col1" class="data row0 col1" >73.473684</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col2" class="data row0 col2" >66.849424</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col3" class="data row0 col3" >17.915789</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col4" class="data row0 col4" >12.630323</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col5" class="data row0 col5" >49.365563</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col6" class="data row0 col6" >51.153282</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col7" class="data row0 col7" >54.373265</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col8" class="data row0 col8" >0.151929</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col9" class="data row0 col9" >12.042437</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row0_col10" class="data row0 col10" >5.626887</td>
#             </tr>
#             <tr>
#                         <th id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col0" class="data row1 col0" >2023-09-11 00:00:00</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col1" class="data row1 col1" >74.160000</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col2" class="data row1 col2" >67.661262</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col3" class="data row1 col3" >18.375000</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col4" class="data row1 col4" >12.742470</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col5" class="data row1 col5" >49.641761</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col6" class="data row1 col6" >51.398065</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col7" class="data row1 col7" >54.798931</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col8" class="data row1 col8" >0.150808</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col9" class="data row1 col9" >10.923848</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row1_col10" class="data row1 col10" >5.877371</td>
#             </tr>
#             <tr>
#                         <th id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col0" class="data row2 col0" >2023-09-18 00:00:00</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col1" class="data row2 col1" >74.190000</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col2" class="data row2 col2" >67.998821</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col3" class="data row2 col3" >17.960000</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col4" class="data row2 col4" >12.931009</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col5" class="data row2 col5" >50.109229</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col6" class="data row2 col6" >52.514610</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col7" class="data row2 col7" >55.042101</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col8" class="data row2 col8" >0.150096</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col9" class="data row2 col9" >11.009656</td>
#                         <td id="T_725f5e80_5c94_11ee_a152_88e9fe6939a8row2_col10" class="data row2 col10" >6.657478</td>
#             </tr>
#     </tbody></table>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# List of player names
player_names = [
    "Colin Bergmann", "Brady Kindhart", "Dominic Sharp", "Elias Stevens",
    "Jordan Rosenberg", "Matthew Arnold", "Steven Schnieder", "Josh Herget",
    "Michael Gould", "Gavin Schacher", "Michael Long", "Camden Ruby",
    "Jack Zebig", "Aaris Stolte", "Andy Bunton", "Matt Schuler",
    "Harry Oden", "Nick Daugherty", "Jacob Hager", "Jordan Stucki",
    "Zach Liggett"
]

# Initialize an empty DataFrame to store individual averages
player_avg_df = pd.DataFrame()

# Outer limits for scaling to percentages
outer_limits = {
    "Bat Speed Avg": 77,
    "Bat Speed Max": 88,
    "Rotational Acceleration Avg": 26,
    "Rotational Acceleration Max": 30,
    "Rotation Score Avg": 80,
    "Connection Score Avg": 80,
    "Plane Score Avg": 80
}

# Loop over all players to read their Excel sheet and calculate the metrics
for name in player_names:
    try:
        sheet = pd.read_excel('/Users/ivanquackenbush/Documents/Maryville baseball/Sept23.xlsx', 
                              sheet_name=name, skiprows=8, engine='openpyxl')
        
        avg_stats = {
            'Bat Speed Avg': sheet['Bat Speed (mph)'].mean(),
            'Bat Speed Max': sheet['Bat Speed (mph)'].max(),
            'Rotational Acceleration Avg': sheet['Rotational Acceleration (g)'].mean(),
            'Rotational Acceleration Max': sheet['Rotational Acceleration (g)'].max(),
            'Rotation Score Avg': sheet['Rotation Score'].mean(),
            'Connection Score Avg': sheet['Connection Score'].mean(),
            'Plane Score Avg': sheet['Plane Score'].mean()
        }
        avg_stats["Name"] = name
        player_avg_df = player_avg_df.append(avg_stats, ignore_index=True)
    
    except Exception as e:
        print(f"An error occurred while processing the sheet for {name}: {str(e)}")

# Calculate team averages from individual averages
team_avgs = player_avg_df.mean()

# Scale team averages to percentages
scaled_team_avgs = [(team_avgs[label] / outer_limits[label]) * 100 for label in outer_limits.keys()]

# Labels for the radar chart
labels = outer_limits.keys()

# Create radar charts
for index, row in player_avg_df.iterrows():
    scaled_values = [(row[label] / outer_limits[label]) * 100 for label in labels]

    fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
    angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
    ax.fill(angles, scaled_values, color='darkgreen', alpha=1)
    ax.fill(angles, scaled_team_avgs, color='lightgreen', alpha=0.6)
    
    # Add percent difference annotations
    for i, angle in enumerate(angles):
        diff = scaled_values[i] - scaled_team_avgs[i]
        ax.annotate(f"{diff:.2f}%", (angle, scaled_values[i]), textcoords="offset points", xytext=(0,10), ha='center', color='black')

    ax.set_xticks(angles)
    ax.set_xticklabels(labels)
    ax.yaxis.grid(True)
    ax.set_yticklabels([])

    plt.legend(loc='upper left', bbox_to_anchor=(1, 1), labels=['Individual', 'Team Average'])
    plt.title(f"{row['Name']}'s Radar Chart Overlayed with Team Averages")
    plt.show()
